# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

louTest = pd.read_csv('assets/incident.csv')
louTest.head()
# Out:
#    IncidentID AgencyORI                    AgencyName IncidentStatusDesc  \
# 0    30217608    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 1    30217610    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 2    30217607    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 3    30217609    568000  LOUISVILLE METRO POLICE DEPT           Accepted
# 4    30217577    568000  LOUISVILLE METRO POLICE DEPT           Accepted
#
#       County RdwyNumber Street  RoadwayName StreetSfx StreetDir  ...  \
# 0  JEFFERSON        NaN   4803    HAZELWOOD       AVE       NaN  ...
# 1  JEFFERSON     KY1065    NaN        OUTER      LOOP       NaN  ...
# 2  JEFFERSON        NaN    840  RIVER CREST        CT       NaN  ...
# 3  JEFFERSON     I 0264    NaN       I264 W       NaN       NaN  ...
# 4  JEFFERSON     I 0065    NaN        I65 N       NaN       NaN  ...
#
#                                      DirAnalysisCode  \
# 0  1 VEHICLE PARKED POSITION (NOT PARKING LOT/DRI...
# 1               SIDESWIPE COLLISION - SAME DIRECTION
# 2  COLLISION WITH FIXED OBJECT NON - INTERSECTION...
# 3  1 VEHICLE PARKED POSITION (NOT PARKING LOT/DRI...
# 4                      OTHER INTERSECTION COLLISIONS
#
#           MannerofCollision     RdwyCharacter  \
# 0                   HEAD ON     CURVE & LEVEL
# 1  SIDESWIPE-SAME DIRECTION  STRAIGHT & GRADE
# 2            SINGLE VEHICLE     CURVE & GRADE
# 3                  REAR END  STRAIGHT & LEVEL
# 4            SINGLE VEHICLE  STRAIGHT & LEVEL
#
#                     LightCondition RampFromRdwyId RampToRdwyId  AcceptedDate  \
# 0  DARK (UNKNOWN ROADWAY LIGHTING)            NaN          NaN  6/23/22 8:07
# 1                         DAYLIGHT            NaN          NaN  6/23/22 8:07
# 2              DARK-HWY LIGHTED/ON            NaN          NaN  6/23/22 8:07
# 3              DARK-HWY LIGHTED/ON            NaN          NaN  6/23/22 8:07
# 4                         DAYLIGHT            NaN          NaN  6/23/22 8:05
#
#    IsSecondaryCollision  OwnerBadge IncidentStatus
# 0                 False        5378       Accepted
# 1                 False        5169       Accepted
# 2                 False        5437       Accepted
# 3                 False        5413       Accepted
# 4                 False        5423       Accepted
#
# [5 rows x 38 columns]

# %%
plt.style.use('seaborn')
plt.figure(figsize = (16, 8))
plt.scatter(louTest['CollisionDate'], louTest['CollisionTime'])
plt.xlabel('Collision Date')
plt.ylabel('Collision Time')
plt.title('Louisville Collisions - Past Month')
# Out:
# Text(0.5, 1.0, 'Louisville Collisions - Past Month')

# %%
cinTest = pd.read_csv('assets/Cincy Crash Data.csv')
cinTest.head()
# Out:
# /var/folders/6f/pzb1mp0j39b1gqfhfdyf0qr80000gn/T/ipykernel_13242/4035067655.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   cinTest = pd.read_csv('assets/Cincy Crash Data.csv')
#          ADDRESS_X  LATITUDE_X  LONGITUDE_X   AGE  \
# 0              NaN         NaN          NaN   NaN
# 1     39XX VINE ST   39.159791   -84.504421   NaN
# 2     XX E 13TH ST   39.109675   -84.517324  37.0
# 3     XX E 13TH ST   39.109915   -84.516584  29.0
# 4  15XX CENTRAL PY   39.111700   -84.521490  34.0
#
#   COMMUNITY_COUNCIL_NEIGHBORHOOD CPD_NEIGHBORHOOD SNA_NEIGHBORHOOD  \
# 0                            NaN              NaN              NaN
# 1                 NORTH AVONDALE   NORTH AVONDALE         AVONDALE
# 2                            OTR   OVER-THE-RHINE   OVER-THE-RHINE
# 3                            OTR   OVER-THE-RHINE   OVER-THE-RHINE
# 4                       WEST END        WEST  END         WEST END
#
#       CRASHDATE  CRASHLOCATION               CRASHSEVERITY  ...  \
# 0  7/10/22 0:02            NaN  3 - MINOR INJURY SUSPECTED  ...
# 1  7/9/22 22:21            NaN    5 - PROPERTY DAMAGE ONLY  ...
# 2  7/9/22 21:18            NaN    5 - PROPERTY DAMAGE ONLY  ...
# 3  7/9/22 21:18            NaN    5 - PROPERTY DAMAGE ONLY  ...
# 4  7/9/22 21:09            NaN    5 - PROPERTY DAMAGE ONLY  ...
#
#                                        MANNEROFCRASH ROADCONDITIONSPRIMARY  \
# 0                                                NaN                   NaN
# 1                      7 - SIDESWIPE, SAME DIRECTION              01 - DRY
# 2  1 - NOT COLLISION BETWEEN TWO MOTOR VEHICLES I...              01 - DRY
# 3  1 - NOT COLLISION BETWEEN TWO MOTOR VEHICLES I...              01 - DRY
# 4                                       2 - REAR-END              01 - DRY
#
#           ROADCONTOUR                        ROADSURFACE ROADCLASS  \
# 0                 NaN                                NaN       NaN
# 1  1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT       NaN
# 2  1 - STRAIGHT LEVEL                       1 - CONCRETE       NaN
# 3  1 - STRAIGHT LEVEL                       1 - CONCRETE       NaN
# 4  2 - STRAIGHT GRADE                       1 - CONCRETE       2.0
#
#           ROADCLASSDESC                UNITTYPE    TYPEOFPERSON    WEATHER  \
# 0                   NaN                     NaN             NaN        NaN
# 1                   NaN                     NaN             NaN  1 - CLEAR
# 2                   NaN      01 - PASSENGER CAR      D - DRIVER  1 - CLEAR
# 3                   NaN  23 - PEDESTRIAN/SKATER  P - PEDESTRIAN  1 - CLEAR
# 4  Major Arterial Roads      01 - PASSENGER CAR      D - DRIVER  1 - CLEAR
#
#      ZIP
# 0    NaN
# 1  45217
# 2  45202
# 3  45202
# 4  45214
#
# [5 rows x 28 columns]

# %%
cinMain = cinTest.filter(["AGE", "CRASHDATE", "INJURIES", "TYPEOFPERSON"], axis=1)
cinMain.head()
# Out:
#     AGE     CRASHDATE                 INJURIES    TYPEOFPERSON
# 0   NaN  7/10/22 0:02                      NaN             NaN
# 1   NaN  7/9/22 22:21                      NaN             NaN
# 2  37.0  7/9/22 21:18  5 - NO APPARENTY INJURY      D - DRIVER
# 3  29.0  7/9/22 21:18  5 - NO APPARENTY INJURY  P - PEDESTRIAN
# 4  34.0  7/9/22 21:09  5 - NO APPARENTY INJURY      D - DRIVER

# %%
cinMain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95178 entries, 0 to 95177
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AGE           81629 non-null  float64
#  1   CRASHDATE     95178 non-null  object
#  2   INJURIES      95085 non-null  object
#  3   TYPEOFPERSON  95090 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 2.9+ MB

# %%
# float64 is a silly dtype for an Age column, but Age isn't always known, so this produces an error for blank entries
#
# cinMain["AGE"] = cinMain["AGE"].astype('int64')

cinMain["CRASHDATE"] = pd.to_datetime(cinMain["CRASHDATE"]).dt.date
cinMain.head()
# Out:
#     AGE   CRASHDATE                 INJURIES    TYPEOFPERSON
# 0   NaN  2022-07-10                      NaN             NaN
# 1   NaN  2022-07-09                      NaN             NaN
# 2  37.0  2022-07-09  5 - NO APPARENTY INJURY      D - DRIVER
# 3  29.0  2022-07-09  5 - NO APPARENTY INJURY  P - PEDESTRIAN
# 4  34.0  2022-07-09  5 - NO APPARENTY INJURY      D - DRIVER

# %%
# Create a new Pandas series with entries for the total number of crashes per day.

# This is good, but a different data format which doesn't have an obvious way to access the computed values.

cinCrashes = cinMain.groupby(["CRASHDATE"]).size()
cinCrashes.head()
# Out:
# CRASHDATE
# 2019-07-09     90
# 2019-07-10    112
# 2019-07-11    100
# 2019-07-12     91
# 2019-07-13    105
# dtype: int64

# %%
cinCrashes.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1098 entries, 2019-07-09 to 2022-07-10
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 1098 non-null   int64
# dtypes: int64(1)
# memory usage: 49.4+ KB

# %%
# plt.style.use('seaborn')
# plt.figure(figsize = (16, 8))
# plt.scatter(cinCrashes['CollisionDate'], louTest['CollisionTime'])
# plt.xlabel('Collision Date')
# plt.ylabel('Collision Time')
# plt.title('Louisville Collisions - Past Month')

cinCrashes.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='CRASHDATE'>

# %% [markdown]
# This gives us a rough bar chart of crashes per day, but the x-axis is a mess.
